# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.set_loglevel("info")

# %%
# Input
df_file = "./results/evaluation_sampled_all.tsv"
out_folder = "./results"

# Set to None if you don't want to use it. Results will not be grouped/filtered by team
names_file = None

# Cumulate the last column of the cols variable, e.g. "pr" --> precision, so that the curves are monotonic as in CAFA
cumulate = True

# Methods with coverage below this threshold will not be plotted
coverage_threshold = 0.3

# Select a metric
metric, cols = ('f', ['rc', 'pr'])
# metric, cols =  ('wf', ['wrc', 'wpr'])
# metric, cols = ('s', ['ru', 'mi'])

# %%
df = pd.read_csv(df_file, sep="\t")
df
# Out:
#                                               filename                  ns  \
# 0                             sample_test_pred_all.tsv  biological_process
# 1                             sample_test_pred_all.tsv  biological_process
# 2                             sample_test_pred_all.tsv  biological_process
# 3                             sample_test_pred_all.tsv  biological_process
# 4                             sample_test_pred_all.tsv  biological_process
# ..                                                 ...                 ...
# 589  .ipynb_checkpoints_sample_test_pred_all-checkp...  cellular_component
# 590  .ipynb_checkpoints_sample_test_pred_all-checkp...  cellular_component
# 591  .ipynb_checkpoints_sample_test_pred_all-checkp...  cellular_component
# 592  .ipynb_checkpoints_sample_test_pred_all-checkp...  cellular_component
# 593  .ipynb_checkpoints_sample_test_pred_all-checkp...  cellular_component
#
#       tau  cov       pr       rc        f
# 0    0.01  1.0  0.13461  0.86811  0.23308
# 1    0.02  1.0  0.17454  0.82390  0.28805
# 2    0.03  1.0  0.20552  0.79095  0.32626
# 3    0.04  1.0  0.23194  0.76306  0.35575
# 4    0.05  1.0  0.25546  0.74070  0.37990
# ..    ...  ...      ...      ...      ...
# 589  0.95  1.0  0.99501  0.27938  0.43627
# 590  0.96  1.0  0.99541  0.26201  0.41483
# 591  0.97  1.0  0.99739  0.23960  0.38638
# 592  0.98  1.0  0.99753  0.21685  0.35625
# 593  0.99  1.0  0.99910  0.18497  0.31215
#
# [594 rows x 7 columns]

# %%
if names_file is None:
    df['group'] = df['filename']
    df['label'] = df['filename']
    df['is_baseline'] = False
else:
    # Set method information (optional)
    methods = pd.read_csv(names_file, delim_whitespace=True, header=0)
    df = pd.merge(df, methods, on='filename', how='left')
    df['group'].fillna(df['filename'], inplace=True)
    df['label'].fillna(df['filename'], inplace=True)
    if 'is_baseline' not in df:
        df['is_baseline'] = False
    else:
        df['is_baseline'].fillna(False, inplace=True)
    print(methods)
df = df.drop(columns='filename').set_index(['group', 'label', 'ns', 'tau'])
df
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  1.0
#                                                                                                                          0.02  1.0
#                                                                                                                          0.03  1.0
#                                                                                                                          0.04  1.0
#                                                                                                                          0.05  1.0
# ...                                                                                                                            ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  1.0
#                                                                                                                          0.96  1.0
#                                                                                                                          0.97  1.0
#                                                                                                                          0.98  1.0
#                                                                                                                          0.99  1.0
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.13461
#                                                                                                                          0.02  0.17454
#                                                                                                                          0.03  0.20552
#                                                                                                                          0.04  0.23194
#                                                                                                                          0.05  0.25546
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.99501
#                                                                                                                          0.96  0.99541
#                                                                                                                          0.97  0.99739
#                                                                                                                          0.98  0.99753
#                                                                                                                          0.99  0.99910
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.86811
#                                                                                                                          0.02  0.82390
#                                                                                                                          0.03  0.79095
#                                                                                                                          0.04  0.76306
#                                                                                                                          0.05  0.74070
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.27938
#                                                                                                                          0.96  0.26201
#                                                                                                                          0.97  0.23960
#                                                                                                                          0.98  0.21685
#                                                                                                                          0.99  0.18497
#
#                                                                                                                                      f  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.23308
#                                                                                                                          0.02  0.28805
#                                                                                                                          0.03  0.32626
#                                                                                                                          0.04  0.35575
#                                                                                                                          0.05  0.37990
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.43627
#                                                                                                                          0.96  0.41483
#                                                                                                                          0.97  0.38638
#                                                                                                                          0.98  0.35625
#                                                                                                                          0.99  0.31215
#
#                                                                                                                                is_baseline
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01        False
#                                                                                                                          0.02        False
#                                                                                                                          0.03        False
#                                                                                                                          0.04        False
#                                                                                                                          0.05        False
# ...                                                                                                                                    ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95        False
#                                                                                                                          0.96        False
#                                                                                                                          0.97        False
#                                                                                                                          0.98        False
#                                                                                                                          0.99        False
#
# [594 rows x 5 columns]

# %%
# Assign colors based on group
cmap = plt.get_cmap('tab20')
df['colors'] = df.index.get_level_values('group')
df['colors'] = pd.factorize(df['colors'])[0]
df['colors'] = df['colors'].apply(lambda x: cmap.colors[x % len(cmap.colors)])
df
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  1.0
#                                                                                                                          0.02  1.0
#                                                                                                                          0.03  1.0
#                                                                                                                          0.04  1.0
#                                                                                                                          0.05  1.0
# ...                                                                                                                            ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  1.0
#                                                                                                                          0.96  1.0
#                                                                                                                          0.97  1.0
#                                                                                                                          0.98  1.0
#                                                                                                                          0.99  1.0
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.13461
#                                                                                                                          0.02  0.17454
#                                                                                                                          0.03  0.20552
#                                                                                                                          0.04  0.23194
#                                                                                                                          0.05  0.25546
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.99501
#                                                                                                                          0.96  0.99541
#                                                                                                                          0.97  0.99739
#                                                                                                                          0.98  0.99753
#                                                                                                                          0.99  0.99910
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.86811
#                                                                                                                          0.02  0.82390
#                                                                                                                          0.03  0.79095
#                                                                                                                          0.04  0.76306
#                                                                                                                          0.05  0.74070
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.27938
#                                                                                                                          0.96  0.26201
#                                                                                                                          0.97  0.23960
#                                                                                                                          0.98  0.21685
#                                                                                                                          0.99  0.18497
#
#                                                                                                                                      f  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.23308
#                                                                                                                          0.02  0.28805
#                                                                                                                          0.03  0.32626
#                                                                                                                          0.04  0.35575
#                                                                                                                          0.05  0.37990
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.43627
#                                                                                                                          0.96  0.41483
#                                                                                                                          0.97  0.38638
#                                                                                                                          0.98  0.35625
#                                                                                                                          0.99  0.31215
#
#                                                                                                                                is_baseline  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01        False
#                                                                                                                          0.02        False
#                                                                                                                          0.03        False
#                                                                                                                          0.04        False
#                                                                                                                          0.05        False
# ...                                                                                                                                    ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95        False
#                                                                                                                          0.96        False
#                                                                                                                          0.97        False
#                                                                                                                          0.98        False
#                                                                                                                          0.99        False
#
#                                                                                                                                                                           colors
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.02  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.03  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.04  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.05  (0.12156862745098039, 0.4666666666666667, 0.70...
# ...                                                                                                                                                                          ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.96  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.97  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.98  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.99  (0.6823529411764706, 0.7803921568627451, 0.909...
#
# [594 rows x 6 columns]

# %%
# Filter by coverage
df = df[df['cov'] >= coverage_threshold]
df
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  1.0
#                                                                                                                          0.02  1.0
#                                                                                                                          0.03  1.0
#                                                                                                                          0.04  1.0
#                                                                                                                          0.05  1.0
# ...                                                                                                                            ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  1.0
#                                                                                                                          0.96  1.0
#                                                                                                                          0.97  1.0
#                                                                                                                          0.98  1.0
#                                                                                                                          0.99  1.0
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.13461
#                                                                                                                          0.02  0.17454
#                                                                                                                          0.03  0.20552
#                                                                                                                          0.04  0.23194
#                                                                                                                          0.05  0.25546
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.99501
#                                                                                                                          0.96  0.99541
#                                                                                                                          0.97  0.99739
#                                                                                                                          0.98  0.99753
#                                                                                                                          0.99  0.99910
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.86811
#                                                                                                                          0.02  0.82390
#                                                                                                                          0.03  0.79095
#                                                                                                                          0.04  0.76306
#                                                                                                                          0.05  0.74070
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.27938
#                                                                                                                          0.96  0.26201
#                                                                                                                          0.97  0.23960
#                                                                                                                          0.98  0.21685
#                                                                                                                          0.99  0.18497
#
#                                                                                                                                      f  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  0.23308
#                                                                                                                          0.02  0.28805
#                                                                                                                          0.03  0.32626
#                                                                                                                          0.04  0.35575
#                                                                                                                          0.05  0.37990
# ...                                                                                                                                ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  0.43627
#                                                                                                                          0.96  0.41483
#                                                                                                                          0.97  0.38638
#                                                                                                                          0.98  0.35625
#                                                                                                                          0.99  0.31215
#
#                                                                                                                                is_baseline  \
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01        False
#                                                                                                                          0.02        False
#                                                                                                                          0.03        False
#                                                                                                                          0.04        False
#                                                                                                                          0.05        False
# ...                                                                                                                                    ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95        False
#                                                                                                                          0.96        False
#                                                                                                                          0.97        False
#                                                                                                                          0.98        False
#                                                                                                                          0.99        False
#
#                                                                                                                                                                           colors
# group                                              label                                              ns                 tau
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.01  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.02  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.03  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.04  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                                          0.05  (0.12156862745098039, 0.4666666666666667, 0.70...
# ...                                                                                                                                                                          ...
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... cellular_component 0.95  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.96  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.97  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.98  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                                          0.99  (0.6823529411764706, 0.7803921568627451, 0.909...
#
# [594 rows x 6 columns]

# %%
# Identify the best methods and thresholds
index_best = df.groupby(level=['group', 'ns'])[metric].idxmax() if metric in ['f', 'wf'] else df.groupby(['group', 'ns'])[metric].idxmin()
index_best
# Out:
# group                                                   ns
# .ipynb_checkpoints_sample_test_pred_all-checkpoint.tsv  biological_process    (.ipynb_checkpoints_sample_test_pred_all-check...
#                                                         cellular_component    (.ipynb_checkpoints_sample_test_pred_all-check...
#                                                         molecular_function    (.ipynb_checkpoints_sample_test_pred_all-check...
# sample_test_pred_all.tsv                                biological_process    (sample_test_pred_all.tsv, sample_test_pred_al...
#                                                         cellular_component    (sample_test_pred_all.tsv, sample_test_pred_al...
#                                                         molecular_function    (sample_test_pred_all.tsv, sample_test_pred_al...
# Name: f, dtype: object

# %%
# Filter the dataframe for the best method and threshold
df_best = df.loc[index_best, ['cov', 'colors'] + cols + [metric]]
df_best
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
#
#                                                                                                                                                                           colors  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       cellular_component 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       molecular_function 0.43  (0.6823529411764706, 0.7803921568627451, 0.909...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       cellular_component 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function 0.43  (0.12156862745098039, 0.4666666666666667, 0.70...
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
#
#                                                                                                                                      f
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324

# %%
# Filter the dataframe for the best methods
df_methods = df.reset_index('tau').loc[[ele[:-1] for ele in index_best], ['tau', 'cov', 'colors'] + cols + [metric]].sort_index()

# Makes the curves monotonic. Cumulative max on the last column of the cols variable, e.g. "pr" --> precision
if cumulate:
    if metric in ['f', 'wf']:
        df_methods[cols[-1]] = df_methods.groupby(level=['label', 'ns'])[cols[-1]].cummax()
    else:
        df_methods[cols[-1]] = df_methods.groupby(level=['label', 'ns'])[cols[-1]].cummin()


# Save to file
df_methods.drop(columns=['colors']).to_csv('{}/fig_{}.tsv'.format(out_folder, metric), float_format="%.3f", sep="\t")
df_methods
# Out:
#                                                                                                                            tau  \
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  0.01
#                                                                                                       biological_process  0.02
#                                                                                                       biological_process  0.03
#                                                                                                       biological_process  0.04
#                                                                                                       biological_process  0.05
# ...                                                                                                                        ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  0.95
#                                                                                                       molecular_function  0.96
#                                                                                                       molecular_function  0.97
#                                                                                                       molecular_function  0.98
#                                                                                                       molecular_function  0.99
#
#                                                                                                                           cov  \
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  1.0
#                                                                                                       biological_process  1.0
#                                                                                                       biological_process  1.0
#                                                                                                       biological_process  1.0
#                                                                                                       biological_process  1.0
# ...                                                                                                                       ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  1.0
#                                                                                                       molecular_function  1.0
#                                                                                                       molecular_function  1.0
#                                                                                                       molecular_function  1.0
#                                                                                                       molecular_function  1.0
#
#                                                                                                                                                                      colors  \
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       biological_process  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       biological_process  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       biological_process  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       biological_process  (0.6823529411764706, 0.7803921568627451, 0.909...
# ...                                                                                                                                                                     ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function  (0.12156862745098039, 0.4666666666666667, 0.70...
#
#                                                                                                                                rc  \
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  0.86811
#                                                                                                       biological_process  0.82390
#                                                                                                       biological_process  0.79095
#                                                                                                       biological_process  0.76306
#                                                                                                       biological_process  0.74070
# ...                                                                                                                           ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  0.31427
#                                                                                                       molecular_function  0.29780
#                                                                                                       molecular_function  0.27128
#                                                                                                       molecular_function  0.24433
#                                                                                                       molecular_function  0.20380
#
#                                                                                                                                pr  \
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  0.13461
#                                                                                                       biological_process  0.17454
#                                                                                                       biological_process  0.20552
#                                                                                                       biological_process  0.23194
#                                                                                                       biological_process  0.25546
# ...                                                                                                                           ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  0.97649
#                                                                                                       molecular_function  0.98006
#                                                                                                       molecular_function  0.98299
#                                                                                                       molecular_function  0.98564
#                                                                                                       molecular_function  0.99065
#
#                                                                                                                                 f
# group                                              label                                              ns
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process  0.23308
#                                                                                                       biological_process  0.28805
#                                                                                                       biological_process  0.32626
#                                                                                                       biological_process  0.35575
#                                                                                                       biological_process  0.37990
# ...                                                                                                                           ...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           molecular_function  0.47550
#                                                                                                       molecular_function  0.45680
#                                                                                                       molecular_function  0.42521
#                                                                                                       molecular_function  0.39159
#                                                                                                       molecular_function  0.33805
#
# [594 rows x 6 columns]

# %%
# Calculate the max coverage across all thresholds
df_best['max_cov'] = df_methods.groupby(level=['group', 'label', 'ns'])['cov'].max()
df_best
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
#
#                                                                                                                                                                           colors  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       cellular_component 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       molecular_function 0.43  (0.6823529411764706, 0.7803921568627451, 0.909...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       cellular_component 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function 0.43  (0.12156862745098039, 0.4666666666666667, 0.70...
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
#
#                                                                                                                                      f  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324
#
#                                                                                                                                max_cov
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31      1.0
#                                                                                                       cellular_component 0.31      1.0
#                                                                                                       molecular_function 0.43      1.0
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31      1.0
#                                                                                                       cellular_component 0.31      1.0
#                                                                                                       molecular_function 0.43      1.0

# %%
# Set a label column for the plot legend
df_best['label'] = df_best.index.get_level_values('label')
df_best['label'] = df_best.agg(lambda x: f"{x['label']} ({metric.upper()}={x[metric]:.3f} C={x['max_cov']:.3f})", axis=1)
df_best
# Out:
#                                                                                                                                cov  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  1.0
#                                                                                                       cellular_component 0.31  1.0
#                                                                                                       molecular_function 0.43  1.0
#
#                                                                                                                                                                           colors  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       cellular_component 0.31  (0.6823529411764706, 0.7803921568627451, 0.909...
#                                                                                                       molecular_function 0.43  (0.6823529411764706, 0.7803921568627451, 0.909...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       cellular_component 0.31  (0.12156862745098039, 0.4666666666666667, 0.70...
#                                                                                                       molecular_function 0.43  (0.12156862745098039, 0.4666666666666667, 0.70...
#
#                                                                                                                                     rc  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.46203
#                                                                                                       cellular_component 0.31  0.70241
#                                                                                                       molecular_function 0.43  0.64353
#
#                                                                                                                                     pr  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.58098
#                                                                                                       cellular_component 0.31  0.76706
#                                                                                                       molecular_function 0.43  0.79990
#
#                                                                                                                                      f  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31  0.51472
#                                                                                                       cellular_component 0.31  0.73331
#                                                                                                       molecular_function 0.43  0.71324
#
#                                                                                                                                max_cov  \
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31      1.0
#                                                                                                       cellular_component 0.31      1.0
#                                                                                                       molecular_function 0.43      1.0
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31      1.0
#                                                                                                       cellular_component 0.31      1.0
#                                                                                                       molecular_function 0.43      1.0
#
#                                                                                                                                                                            label
# group                                              label                                              ns                 tau
# .ipynb_checkpoints_sample_test_pred_all-checkpo... .ipynb_checkpoints_sample_test_pred_all-checkpo... biological_process 0.31  .ipynb_checkpoints_sample_test_pred_all-checkp...
#                                                                                                       cellular_component 0.31  .ipynb_checkpoints_sample_test_pred_all-checkp...
#                                                                                                       molecular_function 0.43  .ipynb_checkpoints_sample_test_pred_all-checkp...
# sample_test_pred_all.tsv                           sample_test_pred_all.tsv                           biological_process 0.31         sample_test_pred_all.tsv (F=0.515 C=1.000)
#                                                                                                       cellular_component 0.31         sample_test_pred_all.tsv (F=0.733 C=1.000)
#                                                                                                       molecular_function 0.43         sample_test_pred_all.tsv (F=0.713 C=1.000)

# %%
plt.rcParams.update({'font.size': 22})

# F-score contour lines
x = np.arange(0.01, 1, 0.01)
y = np.arange(0.01, 1, 0.01)
X, Y = np.meshgrid(x, y)
Z = 2 * X * Y / (X + Y)

for ns, df_g in df_best.groupby(level='ns'):
    fig, ax = plt.subplots(figsize=(15, 15))

     # Contour lines. At the moment they are provided only for the F-score
    if metric in ['f', 'wf']:
        CS = ax.contour(X, Y, Z, np.arange(0.1, 1.0, 0.1), colors='gray')
        ax.clabel(CS, inline=True)#, fontsize=10)

    # Iterate methods
    for i, (index, row) in enumerate(df_g.sort_values(by=[metric, 'max_cov'], ascending=[False if metric in ['f', 'wf'] else True, False]).iterrows()):
        data = df_methods.loc[index[:-1]]
        
        # Precision-recall or mi-ru curves
        ax.plot(data[cols[0]], data[cols[1]], color=row['colors'], label=row['label'], lw=2, zorder=500-i)
        
        # F-max or S-min dots
        ax.plot(row[cols[0]], row[cols[1]], color=row['colors'], marker='o', markersize=12, mfc='none', zorder=1000-i)
        ax.plot(row[cols[0]], row[cols[1]], color=row['colors'], marker='o', markersize=6, zorder=1000-i)

    # Set axes limit
    plt.xlim(0, max(1, df_best.loc[:,:,ns,:][cols[0]].max()))
    plt.ylim(0, max(1, df_best.loc[:,:,ns,:][cols[1]].max()))

    # Set titles
    ax.set_title(ns)
    ax.set_xlabel(cols[0])
    ax.set_ylabel(cols[1])
    
    # Legend
    # ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    leg = ax.legend(markerscale=6)
    for legobj in leg.get_lines():
        legobj.set_linewidth(10.0)

    # Save figure on disk
    plt.savefig("{}/fig_{}_{}.png".format(out_folder, metric, ns), bbox_inches='tight')
    # plt.clf()
